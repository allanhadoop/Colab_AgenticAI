# %%
classifier = pipeline("zero-shot-classification", device="cuda")
result = classifier("Oncology is a field to study cancer", candidate_labels=["technology", "health", "medical"])
print(result)

"""
{'sequence': 'Oncology is a field to study cancer', 'labels': ['medical', 'health', 'technology'], 
'scores': [0.9731733202934265, 0.01420850120484829, 0.012618225999176502]}
"""
