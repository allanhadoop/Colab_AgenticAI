# %%
# it reads a sentence and tries to identify important named items such as 
# people, diseases, drugs, organizations, etc.

ner = pipeline("ner", device="cuda")
result = ner("Patient has specific cancer mutation , so oncologist Donal suggested the therapy for Doxirubicin")
for entity in result:
  print(entity)

"""
{'entity': 'I-PER', 'score': np.float32(0.99886584), 'index': 11, 'word': 'Don', 'start': 53, 'end': 56}
{'entity': 'I-PER', 'score': np.float32(0.996833), 'index': 12, 'word': '##al', 'start': 56, 'end': 58}
{'entity': 'I-MISC', 'score': np.float32(0.9311355), 'index': 17, 'word': 'Do', 'start': 85, 'end': 87}
{'entity': 'I-MISC', 'score': np.float32(0.6694513), 'index': 18, 'word': '##xi', 'start': 87, 'end': 89}
{'entity': 'I-MISC', 'score': np.float32(0.55483586), 'index': 20, 'word': '##bic', 'start': 91, 'end': 94}
{'entity': 'I-MISC', 'score': np.float32(0.67877394), 'index': 21, 'word': '##in', 'start': 94, 'end': 96}
"""
