# %%
import torch
from google.colab import userdata
from huggingface_hub import login
from transformers import pipeline
from diffusers import DiffusionPipeline
from datasets import load_dataset
import soundfile as sf
from IPython.display import Audio

first_sent_analy = pipeline("sentiment-analysis", device = "cuda")
result = first_sent_analy("i am interested and looking forward to learn Pipeline")
print(result)

""" 
[{'label': 'POSITIVE', 'score': 0.9997714161872864}] 
"""

# %%
better_sentiment = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment", device="cuda")
result = better_sentiment("I should be more excited to be on the way to LLM mastery!!")
print(result)

"""
since we use "should be" it is not giving 5 star rating.
[{'label': '3 stars', 'score': 0.39448031783103943}]
"""
