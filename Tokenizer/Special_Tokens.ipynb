# %%
# We need to get Meta llama3.1 model accessed approved on Hugging face. Once it done then use below code
# Below model is base model 
tokenizer = AutoTokenizer.from_pretrained('meta-llama/Meta-Llama-3.1-8B', trust_remote_code=True)

text = "I am excited to show Tokenizers in action to my LLM engineers"
tokens = tokenizer.encode(text)
tokens

"""
[128000,          # This is special token 
 40,
 1097,
 12304,
 311,
 1501,
 9857,
 12509,
 304,
 1957,
 311,
 856,
 445,
 11237,
 25175]
"""

character_count = len(text)
word_count = len(text.split(' '))
token_count = len(tokens)
print(f"There are {character_count} characters, {word_count} words and {token_count} tokens")

# There are 61 characters, 12 words and 15 tokens
tokenizer.decode(tokens)
# ['<|begin_of_text|>I am excited to show Tokenizers in action to my LLM engineers']
# <|begin_of_text|> -- This is special token

# tokenizer.vocab
tokenizer.get_added_vocab()
"""  Below of all special tokens -
{'<|begin_of_text|>': 128000,
 '<|end_of_text|>': 128001,
 '<|reserved_special_token_0|>': 128002,
 '<|reserved_special_token_1|>': 128003,
 '<|finetune_right_pad_id|>': 128004,
 '<|reserved_special_token_2|>': 128005,
 '<|start_header_id|>': 128006,
 '<|end_header_id|>': 128007,
 '<|eom_id|>': 128008,
 '<|eot_id|>': 128009,
 '<|python_tag|>': 128010,
 '<|reserved_special_token_3|>': 128011,
 '<|reserved_special_token_4|>': 128012,
 '<|reserved_special_token_5|>': 128013,
"""

len(tokenizer.vocab)

#  128256   - These many special tokens are there in this model
